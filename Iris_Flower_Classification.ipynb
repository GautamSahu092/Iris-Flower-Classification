# %% [raw]
# Task 1:Iris Flower Classification

# %% [raw]
# Importing Python Modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sn
import warnings
warnings.filterwarnings("ignore")

# %% [raw]
# Data Exploration

# %%
df=pd.read_csv('Iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# Exploration

# %%
df.shape
# Out:
# (150, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
print("Species involved in given dataset:",df["Species"].unique())
# Out:
# Species involved in given dataset: ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']

# %% [raw]
# Data Visualization

# %%
sn.pairplot(df,hue="Species",markers="x")
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sn.scatterplot(x='SepalLengthCm',y='PetalLengthCm',data=df,hue='Species')

plt.subplot(1,2,2)
sn.scatterplot(x='SepalWidthCm',y='PetalWidthCm',data=df,hue='Species')
plt.show()

# %%
numeric_columns = df.select_dtypes(include=[numpy.number])

correlation_matrix = numeric_columns.corr()

print(correlation_matrix)
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
plt.figure(figsize=(10,7))
sn.heatmap(correlation_matrix,annot=True,cmap="Oranges_r")
plt.show()

# %%
df["Species"].value_counts().plot(kind="pie",autopct="%1.1f%%",shadow=True,figsize=(5,5))

plt.show()

# %%
sn.scatterplot(x='SepalLengthCm',y='SepalWidthCm',data=df,hue='Species')
plt.show()

# %%
sn.scatterplot(x='PetalLengthCm',y='PetalWidthCm',data=df,hue='Species')
plt.show()

# %%
sn.jointplot(data=df,x="SepalLengthCm",y="SepalWidthCm",hue="Species")
plt.show()

# %%
sn.jointplot(data=df,x="PetalLengthCm",y="PetalWidthCm",hue="Species")
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sn.barplot(x="Species",y="SepalLengthCm",data=df,palette=("Spectral"))
plt.subplot(1,2,2)
sn.boxplot(x="Species",y="SepalLengthCm",data=df,palette=("Spectral"))

plt.show()

# %%
plt.figure(figsize=(15,5))
plt.subplot(2,2,1)
sn.distplot(df["SepalLengthCm"],color="y").set_title("Sepal Length Interval")
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.subplot(2,2,1)
sn.distplot(df["SepalWidthCm"],color="y").set_title("Sepal Width Interval")
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.subplot(2,2,1)
sn.distplot(df["PetalLengthCm"],color="y").set_title("Petal Length Interval")
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.subplot(2,2,1)
sn.distplot(df["PetalWidthCm"],color="y").set_title("Petal Width Interval")
plt.show()

# %% [raw]
# Data Cleaning

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df["Species"]=le.fit_transform(df["Species"])
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %%
df["Species"].unique()
# Out:
# array([0, 1, 2])

# %%
Y=df.iloc[:,[0,1,2,3]]
Y.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm
# 0   1            5.1           3.5            1.4
# 1   2            4.9           3.0            1.4
# 2   3            4.7           3.2            1.3
# 3   4            4.6           3.1            1.5
# 4   5            5.0           3.6            1.4

# %%
T=df.iloc[:,-1]
T.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Species, dtype: int32

# %% [raw]
# Model Building

# %%
from sklearn.model_selection import train_test_split
Y_train,Y_test,T_train,T_test=train_test_split(Y,T,test_size=0.2,random_state=0)
print(Y_train.shape)
print(Y_test.shape)
print(T_train.shape)
print(T_test.shape)
# Out:
# (120, 4)
# (30, 4)
# (120,)
# (30,)

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(Y_train,T_train)
pred=lr.predict(Y_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
cm=confusion_matrix(T_test,pred)
print("Confusion Matrix:")
print(cm)
accuracy=accuracy_score(T_test,pred)
print("Accuracy Score:",accuracy*100)
print("Classification Report:")
print(classification_report(T_test,pred))
# Out:
# Confusion Matrix:
# [[11  0  0]
#  [ 0 13  0]
#  [ 0  0  6]]
# Accuracy Score: 100.0
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00         6
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()
dtc.fit(Y_train,T_train)
pred_dtc=dtc.predict(Y_test)
cm=confusion_matrix(T_test,pred_dtc)
print("Confusion Matrix:")
print(cm)
accuracy=accuracy_score(T_test,pred_dtc)
print("Accuracy Score:",accuracy*100)
print("Classification Report:")
print(classification_report(T_test,pred_dtc))
# Out:
# Confusion Matrix:
# [[11  0  0]
#  [ 0 13  0]
#  [ 0  1  5]]
# Accuracy Score: 96.66666666666667
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       0.93      1.00      0.96        13
#            2       1.00      0.83      0.91         6
#
#     accuracy                           0.97        30
#    macro avg       0.98      0.94      0.96        30
# weighted avg       0.97      0.97      0.97        30

# %% [raw]
# Accuracy Of LogisticRegressionModel=100%
# Accuracy of DecisionTreeClassifier=96.66%

# %%
from sklearn.tree import plot_tree
features=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']
classes=['Iris-setosa','Iris-versicolor','Iris-virginica']
plt.figure(figsize=(10,10))
plot_tree(dtc,feature_names=features,class_names=classes,filled=True);

# %% [markdown]
# Test Model

# %%
input_data = (4, 9, 3, 0, 1, 4, 0, 2)
input_data_subset = input_data[:4]
input_data_reshaped = np.array(input_data_subset).reshape(1, -1)
predicted_category = dtc.predict(input_data_reshaped)
print("Category:", predicted_category)
# Out:
# Category: [0]
